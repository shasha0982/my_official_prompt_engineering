# %% [markdown]
# # For csv file

# %%
# load dataset

import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/kaggle/input/chatbot-ai-q-and-a/AI.csv')

# %%
data.head(10)
# Out:
#                                             Question  \
# 0  Who did the first work generally recognized as...
# 1  What sources was drawn on the formation of the...
# 2             Who created the Hebbian learning rule?
# 3            When the first neural network is built?
# 4           What is the first neural network called?
# 5                    "Who introduced the Turing test
# 6  Alan Turing prefer what method on creating hum...
# 7             Who presented the Logic Theorist (LT)?
# 8  What does General Problem Solver (GPS) is desi...
# 9  Which model was robably the first program to e...
#
#                                               Answer
# 0        Warren McCulloch and Walter Pitts (1943).\n
# 1  knowledge of the basic physiology and function...
# 2                              Donald Hebb (1949).\n
# 3                                            1950.\n
# 4                                       The SNARC.\n
# 5                                   machine learning
# ...

# %%
data.tail(10)
# Out:
#                                               Question  \
# 493  Does iterative deepening search always find th...
# 494     How long iterative deepening search will take?
# 495                       What is uniform-cost search?
# 496  Does uniform-cost search always find a solutio...
# 497  Does uniform-cost search always find the best ...
# 498            How long uniform-cost search will take?
# 499  How much space does uniform-cost search take t...
# 500  How much space does iterative deepening search...
# 501  How much space does depth-first search take to...
# 502  How much space does breadth-first search take ...
#
#                                                 Answer
# 493  Only if path cost is a non-decreasing function...
# 494      b + (b+b^2) + .......(b+....b^d)  = O(b^d).\n
# 495  Always expand the node on the fringe with mini...
# 496                                             Yes.\n
# 497                                               "Yes
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Question  503 non-null    object
#  1   Answer    503 non-null    object
# dtypes: object(2)
# memory usage: 8.0+ KB

# %%
# check missing values

missing_values = data.isnull().sum()

# %%
missing_values
# Out:
# Question    0
# Answer      0
# dtype: int64

# %% [markdown]
# # Try Q & A with AI

# %%
data['Question'].value_counts()
# Out:
# Question
# What is knowledge engineering?                                                                                           2
# What are linear constraints?                                                                                             1
# Why do we formulate a problem as a CSP?                                                                                  1
# What is a partial solution?                                                                                              1
# What is a partial assignment?                                                                                            1
#                                                                                                                         ..
# What happens in a localist representation?                                                                               1
# ...

# %%
data['Answer'].value_counts()
# Out:
# Answer
# "Yes                                                                                                        4
# "First                                                                                                      3
# Yes.\n                                                                                                      3
# of nodes with path cost ≤ cost of optimal solution.\n                                                       2
# The state that the agent starts in.\n                                                                       2
#                                                                                                            ..
# Intelligent systems for the real world may need to operate at all points along the axis simultaneously\n    1
# Reasoning and learning become more complex as the expressive power of the representation increases.\n       1
# ...

# %%
# !pip install transformers

# %%
# !pip install huggingface

# %% [markdown]
# # Use Answer Q1 with Model Mderberta v3 base squad2

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", "timpal0l/mdeberta-v3-base-squad2")
question = "Who did the first work generally recognized as AI?"
context = "Warren McCulloch and Walter Pitts (1943)."
qa_model(question = question, context = context)
# Out:
# 2024-04-24 12:25:29.154161: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-24 12:25:29.154288: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-24 12:25:29.284707: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# config.json:   0%|          | 0.00/879 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/453 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# ...

# %% [markdown]
# # Use Answer Q2 with model longformer-base-4096-finetuned-squadv2

# %%
# Usage with HF pipleine

from transformers import AutoTokenizer, AutoModelForQuestionAnswering, pipeline

ckpt = "mrm8488/longformer-base-4096-finetuned-squadv2"
tokenizer = AutoTokenizer.from_pretrained(ckpt)
model = AutoModelForQuestionAnswering.from_pretrained(ckpt)

qa = pipeline("question-answering", model=model, tokenizer=tokenizer)

text = "Donald Hebb (1949)."
question = "Who created the Hebbian learning rule?"

qa({"question": question, "context": text})
# Out:
# Some weights of the model checkpoint at mrm8488/longformer-base-4096-finetuned-squadv2 were not used when initializing LongformerForQuestionAnswering: ['longformer.pooler.dense.bias', 'longformer.pooler.dense.weight']
# - This IS expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Input ids are automatically padded from 20 to 512 to be a multiple of `config.attention_window`: 512
# {'score': 0.00033536634873598814,
#  'start': 0,
#  'end': 11,
#  'answer': 'Donald Hebb'}

# %% [markdown]
# # Use Answer Q3 with model google-bert/bert-large-uncased-whole-word-masking-finetuned-squad

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/google-bert/bert-large-uncased-whole-word-masking-finetuned-squad"

headers = {"Authorization": "Bearer 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"}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

output = query({
    "inputs": {
        "question": "Alan Turing prefer what method on creating human-level Al?",
        "context": "He prefer to develop learning algorithms and then teach the machine rather than by programming its i..."
    }
})

print(output)
# Out:
# {'error': 'Model google-bert/bert-large-uncased-whole-word-masking-finetuned-squad is currently loading', 'estimated_time': 53.62302780151367}

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="google-bert/bert-large-uncased-whole-word-masking-finetuned-squad")
question = "Alan Turing prefer what method on creating human-level AI?"
context = "He prefer to develop learning algorithms and then teach the machine rather than by programming its i..."
qa_model(question=question, context=context)
# Out:
# config.json:   0%|          | 0.00/443 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of the model checkpoint at google-bert/bert-large-uncased-whole-word-masking-finetuned-squad were not used when initializing BertForQuestionAnswering: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# ...

# %% [markdown]
# # Use Answer Q3 with model consciousAI/question-answering-roberta-base-s-v2

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="consciousAI/question-answering-roberta-base-s-v2")
question = "Alan Turing prefer what method on creating human-level AI?"
context = "He prefer to develop learning algorithms and then teach the machine rather than by programming its i..."
qa_model(question=question, context=context)
# Out:
# config.json:   0%|          | 0.00/782 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/496M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/957 [00:00<?, ?B/s]
# {'score': 0.4284437894821167,
#  'start': 13,
#  'end': 67,
#  'answer': 'develop learning algorithms and then teach the machine'}

# %% [markdown]
# # Use Answer Q4 with model consciousAI/question-answering-roberta-base-s-v2

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="consciousAI/question-answering-roberta-base-s-v2")
question = "Who presented the Logic Theorist (LT)?"
context = "Allen Newell and Herbert Simon from Carnegie Tech."
qa_model(question=question, context=context)
# Out:
# {'score': 0.964137077331543,
#  'start': 0,
#  'end': 30,
#  'answer': 'Allen Newell and Herbert Simon'}

# %% [markdown]
# # Use Answer Q4 with model Intel/dynamic_tinybert

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="Intel/dynamic_tinybert")
question = "Who presented the Logic Theorist (LT)?"
context = "Allen Newell and Herbert Simon from Carnegie Tech."
qa_model(question=question, context=context)
# Out:
# {'score': 0.49561089277267456,
#  'start': 0,
#  'end': 30,
#  'answer': 'Allen Newell and Herbert Simon'}

# %% [markdown]
# # Use Answer Q5 with model Intel/dynamic_tinybert

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="Intel/dynamic_tinybert")
question = "What is the weak methods in 1969?"
context = "a general-purpose search mechanism trying to string together elementary reasoning steps to find comp..."
qa_model(question=question, context=context)
# Out:
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/351 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# {'score': 0.12994292378425598,
#  'start': 61,
#  'end': 87,
#  'answer': 'elementary reasoning steps'}

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="deepset/tinyroberta-squad2")
question = "What is the weak methods in 1969?"
context = "a general-purpose search mechanism trying to string together elementary reasoning steps to find comp..."
qa_model(question=question, context=context)
# Out:
# config.json:   0%|          | 0.00/835 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/326M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/383 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# {'score': 3.361236636245657e-11,
#  'start': 0,
#  'end': 34,
#  'answer': 'a general-purpose search mechanism'}

# %% [markdown]
# # Use Answer Last Q7 with model deepset/tinyroberta-squad2

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="deepset/tinyroberta-squad2")
question = "What does Minsky's idea of frames (1975) implies?"
context = "assembling facts about particular object and event types and arranging the types into a large taxono..."
qa_model(question=question, context=context)
# Out:
# {'score': 1.664193405304104e-08, 'start': 94, 'end': 100, 'answer': 'taxono'}

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="deepset/bert-large-uncased-whole-word-masking-squad2")
question = "What does Minsky's idea of frames (1975) implies?"
context = "assembling facts about particular object and event types and arranging the types into a large taxono..."
qa_model(question=question, context=context)
# Out:
# config.json:   0%|          | 0.00/540 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of the model checkpoint at deepset/bert-large-uncased-whole-word-masking-squad2 were not used when initializing BertForQuestionAnswering: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/19.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# ...

# %% [markdown]
# # Finished My Project ! If you see my dataset please vote ! Thank You !
