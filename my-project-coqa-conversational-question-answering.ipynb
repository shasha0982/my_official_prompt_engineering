# %% [markdown]
# # Try Using 1 Model Only For Train

# %% [markdown]
# # Q1 : Who recently had heart surgery?

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="mrm8488/longformer-base-4096-finetuned-squadv2")
question = "Who recently had heart surgery?"
context = "Officials of the Chicago Transit Authority said they were investigating. The child, Nicole Hobson, was being taken by her mother to Children's Memorial Hospital about 11 P. M., Wednesday to check her recently inserted pacemaker. The child was stricken about a mile from the hospital. Her mother, May Hobson, 40, said, 'I told the bus driver that my baby had just had heart operation and that she was having a heart failure. He said he couldn't go through the traffic.' Ted Garretson, 28, a passenger who had tried to bring back Nicole's life, said the driver did nothing to help and stopped once to pick up more passengers. When the driver reached a corner where he was to make a turn, a block from the hospital, he told Mrs. Hobson to get off, she said. A transit spokesman said the driver should have made radio call to the control center for help.."
qa_model(question=question, context=context)
# Out:
# 2024-04-24 14:01:17.821423: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-24 14:01:17.821532: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-24 14:01:17.950238: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# config.json:   0%|          | 0.00/757 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/595M [00:00<?, ?B/s]
# ...

# %% [markdown]
# # Q2 : Where did he leave them off?

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="mrm8488/longformer-base-4096-finetuned-squadv2")
question = "where did he leave them off?"
context = "Officials of the Chicago Transit Authority said they were investigating. The child, Nicole Hobson, was being taken by her mother to Children's Memorial Hospital about 11 P. M., Wednesday to check her recently inserted pacemaker. The child was stricken about a mile from the hospital. Her mother, May Hobson, 40, said, 'I told the bus driver that my baby had just had heart operation and that she was having a heart failure. He said he couldn't go through the traffic.' Ted Garretson, 28, a passenger who had tried to bring back Nicole's life, said the driver did nothing to help and stopped once to pick up more passengers. When the driver reached a corner where he was to make a turn, a block from the hospital, he told Mrs. Hobson to get off, she said. A transit spokesman said the driver should have made radio call to the control center for help.."
qa_model(question=question, context=context)
# Out:
# Some weights of the model checkpoint at mrm8488/longformer-base-4096-finetuned-squadv2 were not used when initializing LongformerForQuestionAnswering: ['longformer.pooler.dense.bias', 'longformer.pooler.dense.weight']
# - This IS expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Input ids are automatically padded from 196 to 512 to be a multiple of `config.attention_window`: 512
# {'score': 0.008858748711645603,
#  'start': 624,
#  'end': 656,
#  'answer': 'When the driver reached a corner'}

# %% [markdown]
# # Q3 : Did the driver help?

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="mrm8488/longformer-base-4096-finetuned-squadv2")
question = "Did the driver help?"
context = "Officials of the Chicago Transit Authority said they were investigating. The child, Nicole Hobson, was being taken by her mother to Children's Memorial Hospital about 11 P. M., Wednesday to check her recently inserted pacemaker. The child was stricken about a mile from the hospital. Her mother, May Hobson, 40, said, 'I told the bus driver that my baby had just had heart operation and that she was having a heart failure. He said he couldn't go through the traffic.' Ted Garretson, 28, a passenger who had tried to bring back Nicole's life, said the driver did nothing to help and stopped once to pick up more passengers. When the driver reached a corner where he was to make a turn, a block from the hospital, he told Mrs. Hobson to get off, she said. A transit spokesman said the driver should have made radio call to the control center for help.."
qa_model(question=question, context=context)
# Out:
# Some weights of the model checkpoint at mrm8488/longformer-base-4096-finetuned-squadv2 were not used when initializing LongformerForQuestionAnswering: ['longformer.pooler.dense.bias', 'longformer.pooler.dense.weight']
# - This IS expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Input ids are automatically padded from 194 to 512 to be a multiple of `config.attention_window`: 512
# {'score': 0.4649381935596466,
#  'start': 559,
#  'end': 578,
#  'answer': 'did nothing to help'}

# %% [markdown]
# # Q4 : Who tried to bring Nicole back to life?

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="mrm8488/longformer-base-4096-finetuned-squadv2")
question = "Who tried to bring Nicole back to life?"
context = "Officials of the Chicago Transit Authority said they were investigating. The child, Nicole Hobson, was being taken by her mother to Children's Memorial Hospital about 11 P. M., Wednesday to check her recently inserted pacemaker. The child was stricken about a mile from the hospital. Her mother, May Hobson, 40, said, 'I told the bus driver that my baby had just had heart operation and that she was having a heart failure. He said he couldn't go through the traffic.' Ted Garretson, 28, a passenger who had tried to bring back Nicole's life, said the driver did nothing to help and stopped once to pick up more passengers. When the driver reached a corner where he was to make a turn, a block from the hospital, he told Mrs. Hobson to get off, she said. A transit spokesman said the driver should have made radio call to the control center for help.."
qa_model(question=question, context=context)
# Out:
# Some weights of the model checkpoint at mrm8488/longformer-base-4096-finetuned-squadv2 were not used when initializing LongformerForQuestionAnswering: ['longformer.pooler.dense.bias', 'longformer.pooler.dense.weight']
# - This IS expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Input ids are automatically padded from 198 to 512 to be a multiple of `config.attention_window`: 512
# {'score': 0.9929604530334473,
#  'start': 469,
#  'end': 482,
#  'answer': 'Ted Garretson'}

# %% [markdown]
# # Q5 : How old is Ted?

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="mrm8488/longformer-base-4096-finetuned-squadv2")
question = "How old is Ted?"
context = "Officials of the Chicago Transit Authority said they were investigating. The child, Nicole Hobson, was being taken by her mother to Children's Memorial Hospital about 11 P. M., Wednesday to check her recently inserted pacemaker. The child was stricken about a mile from the hospital. Her mother, May Hobson, 40, said, 'I told the bus driver that my baby had just had heart operation and that she was having a heart failure. He said he couldn't go through the traffic.' Ted Garretson, 28, a passenger who had tried to bring back Nicole's life, said the driver did nothing to help and stopped once to pick up more passengers. When the driver reached a corner where he was to make a turn, a block from the hospital, he told Mrs. Hobson to get off, she said. A transit spokesman said the driver should have made radio call to the control center for help.."
qa_model(question=question, context=context)
# Out:
# Some weights of the model checkpoint at mrm8488/longformer-base-4096-finetuned-squadv2 were not used when initializing LongformerForQuestionAnswering: ['longformer.pooler.dense.bias', 'longformer.pooler.dense.weight']
# - This IS expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# {'score': 0.4566428065299988, 'start': 484, 'end': 486, 'answer': '28'}

# %% [markdown]
# # Q6 : Did the driver try to pick more people up?

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="mrm8488/longformer-base-4096-finetuned-squadv2")
question = "Did the driver try to pick more people up?"
context = "Officials of the Chicago Transit Authority said they were investigating. The child, Nicole Hobson, was being taken by her mother to Children's Memorial Hospital about 11 P. M., Wednesday to check her recently inserted pacemaker. The child was stricken about a mile from the hospital. Her mother, May Hobson, 40, said, 'I told the bus driver that my baby had just had heart operation and that she was having a heart failure. He said he couldn't go through the traffic.' Ted Garretson, 28, a passenger who had tried to bring back Nicole's life, said the driver did nothing to help and stopped once to pick up more passengers. When the driver reached a corner where he was to make a turn, a block from the hospital, he told Mrs. Hobson to get off, she said. A transit spokesman said the driver should have made radio call to the control center for help.."
qa_model(question=question, context=context)
# Out:
# Some weights of the model checkpoint at mrm8488/longformer-base-4096-finetuned-squadv2 were not used when initializing LongformerForQuestionAnswering: ['longformer.pooler.dense.bias', 'longformer.pooler.dense.weight']
# - This IS expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Input ids are automatically padded from 199 to 512 to be a multiple of `config.attention_window`: 512
# {'score': 0.5426120162010193,
#  'start': 583,
#  'end': 622,
#  'answer': 'stopped once to pick up more passengers'}

# %% [markdown]
# # Q7 : Who is looking into the situation?

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="mrm8488/longformer-base-4096-finetuned-squadv2")
question = "Who is looking into the situation?"
context = "Officials of the Chicago Transit Authority said they were investigating. The child, Nicole Hobson, was being taken by her mother to Children's Memorial Hospital about 11 P. M., Wednesday to check her recently inserted pacemaker. The child was stricken about a mile from the hospital. Her mother, May Hobson, 40, said, 'I told the bus driver that my baby had just had heart operation and that she was having a heart failure. He said he couldn't go through the traffic.' Ted Garretson, 28, a passenger who had tried to bring back Nicole's life, said the driver did nothing to help and stopped once to pick up more passengers. When the driver reached a corner where he was to make a turn, a block from the hospital, he told Mrs. Hobson to get off, she said. A transit spokesman said the driver should have made radio call to the control center for help.."
qa_model(question=question, context=context)
# Out:
# Some weights of the model checkpoint at mrm8488/longformer-base-4096-finetuned-squadv2 were not used when initializing LongformerForQuestionAnswering: ['longformer.pooler.dense.bias', 'longformer.pooler.dense.weight']
# - This IS expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# {'score': 0.6182301640510559,
#  'start': 17,
#  'end': 42,
#  'answer': 'Chicago Transit Authority'}

# %% [markdown]
# # Q8 : Where was May heading with Nicole?

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="mrm8488/longformer-base-4096-finetuned-squadv2")
question = "Where was May heading with Nicole?"
context = "Officials of the Chicago Transit Authority said they were investigating. The child, Nicole Hobson, was being taken by her mother to Children's Memorial Hospital about 11 P. M., Wednesday to check her recently inserted pacemaker. The child was stricken about a mile from the hospital. Her mother, May Hobson, 40, said, 'I told the bus driver that my baby had just had heart operation and that she was having a heart failure. He said he couldn't go through the traffic.' Ted Garretson, 28, a passenger who had tried to bring back Nicole's life, said the driver did nothing to help and stopped once to pick up more passengers. When the driver reached a corner where he was to make a turn, a block from the hospital, he told Mrs. Hobson to get off, she said. A transit spokesman said the driver should have made radio call to the control center for help.."
qa_model(question=question, context=context)
# Out:
# Some weights of the model checkpoint at mrm8488/longformer-base-4096-finetuned-squadv2 were not used when initializing LongformerForQuestionAnswering: ['longformer.pooler.dense.bias', 'longformer.pooler.dense.weight']
# - This IS expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# {'score': 0.0009246920817531645,
#  'start': 252,
#  'end': 264,
#  'answer': 'about a mile'}

# %% [markdown]
# # Q9 : What day?

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="mrm8488/longformer-base-4096-finetuned-squadv2")
question = "What day?"
context = "Officials of the Chicago Transit Authority said they were investigating. The child, Nicole Hobson, was being taken by her mother to Children's Memorial Hospital about 11 P. M., Wednesday to check her recently inserted pacemaker. The child was stricken about a mile from the hospital. Her mother, May Hobson, 40, said, 'I told the bus driver that my baby had just had heart operation and that she was having a heart failure. He said he couldn't go through the traffic.' Ted Garretson, 28, a passenger who had tried to bring back Nicole's life, said the driver did nothing to help and stopped once to pick up more passengers. When the driver reached a corner where he was to make a turn, a block from the hospital, he told Mrs. Hobson to get off, she said. A transit spokesman said the driver should have made radio call to the control center for help.."
qa_model(question=question, context=context)
# Out:
# Some weights of the model checkpoint at mrm8488/longformer-base-4096-finetuned-squadv2 were not used when initializing LongformerForQuestionAnswering: ['longformer.pooler.dense.bias', 'longformer.pooler.dense.weight']
# - This IS expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Input ids are automatically padded from 192 to 512 to be a multiple of `config.attention_window`: 512
# {'score': 0.1272924691438675, 'start': 177, 'end': 186, 'answer': 'Wednesday'}

# %% [markdown]
# # Q10 : What had recently been put into nicole?

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="mrm8488/longformer-base-4096-finetuned-squadv2")
question = "What had recently been put into nicole?"
context = "Officials of the Chicago Transit Authority said they were investigating. The child, Nicole Hobson, was being taken by her mother to Children's Memorial Hospital about 11 P. M., Wednesday to check her recently inserted pacemaker. The child was stricken about a mile from the hospital. Her mother, May Hobson, 40, said, 'I told the bus driver that my baby had just had heart operation and that she was having a heart failure. He said he couldn't go through the traffic.' Ted Garretson, 28, a passenger who had tried to bring back Nicole's life, said the driver did nothing to help and stopped once to pick up more passengers. When the driver reached a corner where he was to make a turn, a block from the hospital, he told Mrs. Hobson to get off, she said. A transit spokesman said the driver should have made radio call to the control center for help.."
qa_model(question=question, context=context)
# Out:
# Some weights of the model checkpoint at mrm8488/longformer-base-4096-finetuned-squadv2 were not used when initializing LongformerForQuestionAnswering: ['longformer.pooler.dense.bias', 'longformer.pooler.dense.weight']
# - This IS expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# {'score': 0.4188389778137207, 'start': 218, 'end': 227, 'answer': 'pacemaker'}

# %% [markdown]
# # Q11 : What time were they going to the hospital?

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="mrm8488/longformer-base-4096-finetuned-squadv2")
question = "What time were they going to the hospital?"
context = "Officials of the Chicago Transit Authority said they were investigating. The child, Nicole Hobson, was being taken by her mother to Children's Memorial Hospital about 11 P. M., Wednesday to check her recently inserted pacemaker. The child was stricken about a mile from the hospital. Her mother, May Hobson, 40, said, 'I told the bus driver that my baby had just had heart operation and that she was having a heart failure. He said he couldn't go through the traffic.' Ted Garretson, 28, a passenger who had tried to bring back Nicole's life, said the driver did nothing to help and stopped once to pick up more passengers. When the driver reached a corner where he was to make a turn, a block from the hospital, he told Mrs. Hobson to get off, she said. A transit spokesman said the driver should have made radio call to the control center for help.."
qa_model(question=question, context=context)
# Out:
# Some weights of the model checkpoint at mrm8488/longformer-base-4096-finetuned-squadv2 were not used when initializing LongformerForQuestionAnswering: ['longformer.pooler.dense.bias', 'longformer.pooler.dense.weight']
# - This IS expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# {'score': 0.7405178546905518, 'start': 167, 'end': 176, 'answer': '11 P. M.,'}

# %% [markdown]
# # Q12 : What is the mother's name?

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="mrm8488/longformer-base-4096-finetuned-squadv2")
question = "What is the mother's name?"
context = "Officials of the Chicago Transit Authority said they were investigating. The child, Nicole Hobson, was being taken by her mother to Children's Memorial Hospital about 11 P. M., Wednesday to check her recently inserted pacemaker. The child was stricken about a mile from the hospital. Her mother, May Hobson, 40, said, 'I told the bus driver that my baby had just had heart operation and that she was having a heart failure. He said he couldn't go through the traffic.' Ted Garretson, 28, a passenger who had tried to bring back Nicole's life, said the driver did nothing to help and stopped once to pick up more passengers. When the driver reached a corner where he was to make a turn, a block from the hospital, he told Mrs. Hobson to get off, she said. A transit spokesman said the driver should have made radio call to the control center for help.."
qa_model(question=question, context=context)
# Out:
# Some weights of the model checkpoint at mrm8488/longformer-base-4096-finetuned-squadv2 were not used when initializing LongformerForQuestionAnswering: ['longformer.pooler.dense.bias', 'longformer.pooler.dense.weight']
# - This IS expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# {'score': 0.9689615964889526, 'start': 296, 'end': 306, 'answer': 'May Hobson'}

# %% [markdown]
# # Q13 : How old is she?

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", model="mrm8488/longformer-base-4096-finetuned-squadv2")
question = "How old is she?"
context = "Officials of the Chicago Transit Authority said they were investigating. The child, Nicole Hobson, was being taken by her mother to Children's Memorial Hospital about 11 P. M., Wednesday to check her recently inserted pacemaker. The child was stricken about a mile from the hospital. Her mother, May Hobson, 40, said, 'I told the bus driver that my baby had just had heart operation and that she was having a heart failure. He said he couldn't go through the traffic.' Ted Garretson, 28, a passenger who had tried to bring back Nicole's life, said the driver did nothing to help and stopped once to pick up more passengers. When the driver reached a corner where he was to make a turn, a block from the hospital, he told Mrs. Hobson to get off, she said. A transit spokesman said the driver should have made radio call to the control center for help.."
qa_model(question=question, context=context)
# Out:
# Some weights of the model checkpoint at mrm8488/longformer-base-4096-finetuned-squadv2 were not used when initializing LongformerForQuestionAnswering: ['longformer.pooler.dense.bias', 'longformer.pooler.dense.weight']
# - This IS expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LongformerForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# {'score': 0.0025306909810751677, 'start': 308, 'end': 310, 'answer': '40'}

# %% [markdown]
# # Completed Story 1
